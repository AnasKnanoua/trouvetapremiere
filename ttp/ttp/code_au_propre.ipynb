# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\anask\Downloads\fr-esr-parcoursup.csv",sep = ";")





liste_filiere_agregee = list(df["Filière de formation très agrégée"].unique())
liste_region = list(df["Région de l’établissement"].unique())
liste_etablissement = list(df["Établissement"].unique())

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
def moyenne_gen_pro_tech(filiere):
    df_prepa = df[df["Filière de formation"]==filiere]
    df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
    #print(display(df_prepa))
    return df_prepa

# %%
def moyenne_selon_filiere(filiere):
  """Les filières sont general pro ou techno"""

  if filiere == "pro":
      return moyenne_filiere(df_moyenne_pro,r"% d’admis néo bacheliers professionnels")
  elif filiere == "general":
    return moyenne_filiere(df_moyenne_general,r"% d’admis néo bacheliers généraux")
  else:
    return moyenne_filiere(df_moyenne_techno,r"% d’admis néo bacheliers technologiques")


def moyenne_par_formation_detaillee(formation):
  """Les formations sont DCG, prepa... (il y en a 51)"""
  return moyenne_gen_pro_tech(formation)
  
def moyenne_par_formation_agregee(formation):
  """Ces formations sont : (il y en a 11)
  'Autre formation', 'BTS', 'BUT', 'CPGE', 'Licence', "Ecole d'Ingénieur", 'Ecole de Commerce', 'IFSI', 'EFTS', 'PASS', 'Licence_Las'"""
  df_prepa = df[df["Filière de formation très agrégée"]==formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  #print(display(df_prepa))
  return df_prepa
def moyenne_par_filiere_bis(filiere):
  
  df_prepa = df[df["Filière de formation"]==filiere]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa

def moyenne_par_etablissement(etablissement):
  """Les établissements sont les noms exactes (il y en a 3505). 
  Il faudrait rajouter un code permettant de retrouver un établissement selon la recherche d'un utilisateur """
  df_prepa = df[df["Établissement"]==etablissement]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_region(region):
  """Il y a 21 régions différentes"""
  df_prepa = df[df["Région de l’établissement"]==region]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa

def moyenne_par_region_et_formation(region,formation):
  df_prepa = df[df["Région de l’établissement"]==region]
  df_prepa = df_prepa[df_prepa["Filière de formation"] == formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_ville_et_formation(region,formation):
  df_prepa = df[df["Commune de l’établissement"]==region]
  df_prepa = df_prepa[df_prepa["Filière de formation"] == formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_departement_et_formation(region,formation):
  df_prepa = df[df["Département de l’établissement"]==region]
  df_prepa = df_prepa[df_prepa["Filière de formation"] == formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_region_et_formation_agregee(region,formation):
  df_prepa = df[df["Région de l’établissement"]==region]
  df_prepa = df_prepa[df_prepa["Filière de formation très agrégée"] == formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_ville_et_formation_agregee(region,formation):
  df_prepa = df[df["Commune de l’établissement"]==region]
  df_prepa = df_prepa[df_prepa["Filière de formation très agrégée"] == formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_departement_et_formation_agregee(region,formation):
  df_prepa = df[df["Département de l’établissement"]==region]
  df_prepa = df_prepa[df_prepa["Filière de formation très agrégée"] == formation]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_ville(region):
  """Il y a 21 régions différentes"""
  df_prepa = df[df["Commune de l’établissement"]==region]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
def moyenne_par_departement(region):
  """Il y a 21 régions différentes"""
  df_prepa = df[df["Département de l’établissement"]==region]
  df_prepa = df_prepa[["Filière de formation très agrégée","Filière de formation","Filière de formation détaillée bis","LIB_FOR_VOE_INS","Région de l’établissement","Commune de l’établissement","Département de l’établissement","Établissement",r"% d’admis néo bacheliers généraux",r"% d’admis néo bacheliers professionnels",r"% d’admis néo bacheliers technologiques"]]
  return df_prepa
moyenne_par_region_et_formation("Ile-de-France","Licence - STAPS")
#moyenne_par_formation_detaillee("DCG")
#moyenne_par_etablissement("Lycée Newton-Enrea")
#moyenne_par_region("Ile-de-France")
#moyenne_par_formation_agregee("Ecole de Commerce")
#moyenne_par_region_et_formation_agregee("Ile-de-France","CPGE")
#moyenne_par_ville("Marseille")
#ddd[ddd["Filière de formation très agrégée"]=="BUT"]
# Out:
# "['Licence']"

# %%
liste_lieux = []

liste_de_regions = list(df["Région de l’établissement"].unique())
liste_departement = list(df["Département de l’établissement"].unique())
liste_ville = list(df["Commune de l’établissement"].unique())
for reg in liste_de_regions:
    if reg not in liste_lieux:
        liste_lieux.append(reg)
for dep in liste_departement:
    if dep not in liste_lieux:
        liste_lieux.append(dep)
for ville in liste_ville:
    if ville not in liste_lieux:
        liste_lieux.append(ville)

# %%
liste_de_filiere = list(df["Filière de formation"].unique())

# %%
def probas(dfi):    
    proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
    proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
    proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
    t_uple = (proba_g,proba_p,proba_t)
    return t_uple

# %%
def affichage(lieu,choix_dep,choix_ville,choix_fil):
    if lieu != "" and choix_dep!="Selection" and choix_ville=="Selection" and choix_fil=="Selection" :
        dfi = moyenne_par_region_et_formation_agregee(lieu,choix_dep)
        if len(dfi)!=0:
            li = list(dfi["Filière de formation"].unique())
            return probas(dfi)
        else:
            dfi = moyenne_par_departement_et_formation_agregee(lieu,choix_dep)
            if len(dfi)!=0:
                li = list(dfi["Filière de formation"].unique())
                return probas(dfi),li
            else:
                dfi = moyenne_par_ville_et_formation_agregee(lieu,choix_dep)
                li = list(dfi["Filière de formation"].unique())
                return probas(dfi),li

    elif lieu != "" and choix_dep!="Selection" and choix_ville!="Selection" and choix_fil=="Selection" :
        dfi = moyenne_par_region_et_formation(lieu,choix_ville)
        if len(dfi)!=0:
            li = list(dfi["Filière de formation"].unique())
            precedent = list(dfi["Filière de formation très agrégée"].unique())[0]
            return probas(dfi),li,precedent
        else:
            dfi = moyenne_par_departement_et_formation(lieu,choix_dep)
            if len(dfi)!=0:
                li = list(dfi["Filière de formation"].unique())
                precedent = list(dfi["Filière de formation très agrégée"].unique())[0]
                return probas(dfi),li,precedent
            else:
                dfi = moyenne_par_ville_et_formation(lieu,choix_dep)
                li = list(dfi["Filière de formation"].unique())
                precedent = list(dfi["Filière de formation très agrégée"].unique())[0]
                return probas(dfi),li,precedent

# %%
#NO
def change_deroulante(lieu,choix_dep,choix_ville,choix_fil):
  if lieu != "" and choix_dep!="Selection" and choix_ville=="Selection" and choix_fil=="Selection" :
    dfi = moyenne_par_region_et_formation_agregee(lieu,choix_dep)
    if len(dfi)!=0:
        return probas(dfi)
    else:
        dfi = moyenne_par_departement_et_formation_agregee(lieu,choix_dep)
        if len(dfi)!=0:
            return probas(dfi)
        else:
            dfi = moyenne_par_ville_et_formation_agregee(lieu,choix_dep)
            return probas(dfi)

# %%
#fake
def affichage(lieu,choix_dep,choix_ville,choix_fil):
    if lieu != "" and choix_dep!="Selection" and choix_ville=="Selection" and choix_fil=="Selection" :
        dfi = moyenne_par_region_et_formation_agregee(lieu,choix_dep)
        proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
        proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
        proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
        t_uple = (proba_g,proba_p,proba_t)
        return t_uple

# %% [markdown]
# for fil in liste_filiere_agregee:
#     for reg in liste_de_regions:
#
#
#         df_bis = moyenne_par_region_et_formation_agregee(reg,fil)
#         df_bis = df_bis.reset_index()
#         for filiere in liste_de_filiere:
#             dfi = df_bis[df_bis["Filière de formation"]==filiere]
#
#
#             proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
#             proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
#             proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
#             t_uple = str((proba_g,proba_p,proba_t))
#
#             print('if (filiere == "'+filiere+'" && lieu == "'+reg+'"){\nli.push'+t_uple+'\n}')

# %% [markdown]
# for fil in liste_filiere_agregee:
#     for reg in liste_de_regions:
#
#
#         df_bis = moyenne_par_region_et_formation_agregee(reg,fil)
#         df_bis = df_bis.reset_index()
#         for filiere in liste_de_filiere:
#             dfi = df_bis[df_bis["Filière de formation"]==filiere]
#
#
#             proba_g = str(round(df_bis["% d’admis néo bacheliers généraux"].mean(),2))+" %"
#             proba_p = str(round(df_bis["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
#             proba_t = str(round(df_bis["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
#             t_uple = str((proba_g,proba_p,proba_t))
#
#             print('if (filiere == "'+fil+'" && lieu == "'+reg+'"){\nli.push'+t_uple+'\n}')

# %% [markdown]
# df_moyenne_pro = pd.DataFrame(columns = ["filiere","moyenne"])
# df_moyenne_techno = pd.DataFrame(columns = ["filiere","moyenne"])
# df_moyenne_general = pd.DataFrame(columns = ["filiere","moyenne"])
#
# def moyenne_filiere_det(dff,colonne):
#     i = 0
#     for filiere in liste_de_filiere:
#         dfi = df[df["Filière de formation"]==filiere]
#         a = dfi[[colonne,"Filière de formation"]]
#         moyenne = a[colonne].mean()
#         df2 = pd.DataFrame({"filiere":filiere,"moyenne":moyenne},index = [i])
#
#         dff = pd.concat([dff,df2])
#         i+=1
#     return dff
# df_pro_det = moyenne_filiere_det(df_moyenne_pro,r"% d’admis néo bacheliers professionnels")
# df_gen_det = moyenne_filiere_det(df_moyenne_general,r"% d’admis néo bacheliers généraux")
# df_tech_det = moyenne_filiere_det(df_moyenne_techno,r"% d’admis néo bacheliers technologiques")

# %%
for fil in liste_filiere_agregee:
    for reg in liste_de_regions:
    
        #print(reg,fil)
        df_bis = moyenne_par_region_et_formation_agregee(reg,fil)
        df_bis = df_bis.reset_index()      
        for filiere in liste_de_filiere:
            dfi = df_bis[df_bis["Filière de formation"]==filiere]
            if len(dfi)!=0:
                proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
                proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
                proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
                t_uple = str((proba_g,proba_p,proba_t))
            
                print('if (filiere == "'+filiere+'" && filiere_agregee == "'+fil+'" &&  lieu == "'+reg+'"){\nli.push'+t_uple+'\n}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 for fil in liste_filiere_agregee:
# ----> 2     for reg in liste_de_regions:
#       3
#       4         #print(reg,fil)
#       5         df_bis = moyenne_par_region_et_formation_agregee(reg,fil)
#       6         df_bis = df_bis.reset_index()
#
# NameError: name 'liste_de_regions' is not defined

# %%
for fil in liste_filiere_agregee:
    for ville in liste_ville:
    
        #print(reg,fil)
        df_bis = moyenne_par_ville_et_formation_agregee(ville,fil)
        df_bis = df_bis.reset_index()      
        for filiere in liste_de_filiere:
            dfi = df_bis[df_bis["Filière de formation"]==filiere]
            if len(dfi)!=0:
                proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
                proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
                proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
                t_uple = str((proba_g,proba_p,proba_t))
                
                print('if (filiere == "'+filiere+'" && filiere_agregee == "'+fil+'" &&  lieu == "'+ville+'"){\nli.push'+t_uple+'\n}')
# Out:
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "La Roche-sur-Foron"){
# li.push('43.8 %', '0.0 %', '56.3 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Thonon-les-Bains"){
# li.push('87.5 %', '4.2 %', '8.3 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Annecy"){
# li.push('58.59 %', '0.0 %', '41.4 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Annecy"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Annecy"){
# li.push('88.89 %', '0.0 %', '11.1 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Paris  3e  Arrondissement"){
# li.push('82.89 %', '0.0 %', '17.1 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris  3e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris  3e  Arrondissement"){
# li.push('16.8 %', '62.25 %', '20.9 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris  3e  Arrondissement"){
# li.push('55.09 %', '2.41 %', '42.49 %')
# }
# if (filiere == "Diplôme d'Etablissement" && filiere_agregee == "Autre formation" &&  lieu == "Paris  3e  Arrondissement"){
# li.push('51.9 %', '7.4 %', '40.7 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Paris 19e  Arrondissement"){
# li.push('90.55 %', '2.22 %', '7.25 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 19e  Arrondissement"){
# li.push('0.0 %', '75.0 %', '25.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris 19e  Arrondissement"){
# li.push('73.1 %', '4.77 %', '22.13 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Paris  5e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris  5e  Arrondissement"){
# li.push('44.4 %', '0.0 %', '55.59 %')
# }
# if (filiere == "CPES" && filiere_agregee == "Autre formation" &&  lieu == "Paris  5e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formation des écoles supérieure d'art" && filiere_agregee == "Autre formation" &&  lieu == "Paris  5e  Arrondissement"){
# li.push('47.09 %', '5.9 %', '47.09 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('89.69 %', '2.8 %', '7.5 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('92.89 %', '0.0 %', '7.1 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('94.45 %', '0.0 %', '5.55 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('49.54 %', '12.5 %', '37.96 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('52.2 %', '14.7 %', '33.2 %')
# }
# if (filiere == "Diplôme d'Etablissement" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formation des écoles supérieures de cuisine" && filiere_agregee == "Autre formation" &&  lieu == "Paris  6e  Arrondissement"){
# li.push('84.59 %', '0.0 %', '15.4 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris  9e  Arrondissement"){
# li.push('0.0 %', '60.0 %', '40.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 10e  Arrondissement"){
# li.push('66.69 %', '5.6 %', '27.8 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 11e  Arrondissement"){
# li.push('0.0 %', '95.82 %', '4.17 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris 11e  Arrondissement"){
# li.push('71.9 %', '0.0 %', '28.1 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 12e  Arrondissement"){
# li.push('48.7 %', '0.0 %', '51.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 12e  Arrondissement"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris 12e  Arrondissement"){
# li.push('52.08 %', '4.67 %', '43.25 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Paris 13e  Arrondissement"){
# li.push('63.0 %', '0.0 %', '37.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Paris 13e  Arrondissement"){
# li.push('92.09 %', '2.9 %', '5.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 13e  Arrondissement"){
# li.push('67.37 %', '0.0 %', '32.62 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 13e  Arrondissement"){
# li.push('33.3 %', '55.59 %', '11.1 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris 13e  Arrondissement"){
# li.push('44.28 %', '12.23 %', '43.49 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris 18e  Arrondissement"){
# li.push('18.5 %', '0.0 %', '81.49 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Paris 14e  Arrondissement"){
# li.push('97.0 %', '0.0 %', '3.0 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Paris 14e  Arrondissement"){
# li.push('72.69 %', '9.1 %', '18.2 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 14e  Arrondissement"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Paris 14e  Arrondissement"){
# li.push('88.89 %', '5.6 %', '5.6 %')
# }
# if (filiere == "Formation des écoles supérieure d'art" && filiere_agregee == "Autre formation" &&  lieu == "Paris 14e  Arrondissement"){
# li.push('82.8 %', '0.0 %', '17.2 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 15e  Arrondissement"){
# li.push('81.23 %', '0.0 %', '18.77 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 15e  Arrondissement"){
# li.push('0.0 %', '80.0 %', '20.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Paris 15e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Paris 15e  Arrondissement"){
# li.push('45.64 %', '5.58 %', '48.79 %')
# }
# if (filiere == "Formation des écoles supérieure d'art" && filiere_agregee == "Autre formation" &&  lieu == "Paris 15e  Arrondissement"){
# li.push('85.53 %', '5.07 %', '9.47 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 16e  Arrondissement"){
# li.push('12.5 %', '31.3 %', '56.3 %')
# }
# if (filiere == "CPES" && filiere_agregee == "Autre formation" &&  lieu == "Paris 16e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formation valant grade de licence" && filiere_agregee == "Autre formation" &&  lieu == "Paris 16e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Paris 17e  Arrondissement"){
# li.push('63.0 %', '0.0 %', '37.0 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Paris 17e  Arrondissement"){
# li.push('64.5 %', '0.0 %', '35.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 17e  Arrondissement"){
# li.push('0.0 %', '80.0 %', '20.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 20e  Arrondissement"){
# li.push('65.19 %', '4.3 %', '30.4 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris 20e  Arrondissement"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Diplôme d'établissement" && filiere_agregee == "Autre formation" &&  lieu == "Paris 20e  Arrondissement"){
# li.push('81.8 %', '9.1 %', '9.1 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Paris"){
# li.push('88.62 %', '4.85 %', '6.52 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Paris  7e  Arrondissement"){
# li.push('80.59 %', '0.0 %', '19.4 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Paris  7e  Arrondissement"){
# li.push('38.09 %', '33.3 %', '28.6 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Paris  7e  Arrondissement"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Paris  7e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('44.4 %', '0.0 %', '55.59 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('90.0 %', '0.0 %', '10.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('74.54 %', '15.45 %', '10.05 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('28.05 %', '12.15 %', '59.79 %')
# }
# if (filiere == "Diplôme d'Etablissement" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('63.59 %', '36.4 %', '0.0 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Le Havre"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('56.8 %', '0.0 %', '43.2 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('79.8 %', '0.0 %', '20.2 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('71.39 %', '7.1 %', '21.4 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('86.69 %', '0.0 %', '13.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('53.15 %', '0.0 %', '46.9 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Rouen"){
# li.push('63.59 %', '9.1 %', '27.3 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Darnétal"){
# li.push('84.39 %', '8.3 %', '7.3 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Mont-Saint-Aignan"){
# li.push('0.0 %', '93.3 %', '6.7 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Le Grand-Quevilly"){
# li.push('0.0 %', '72.69 %', '27.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Avon"){
# li.push('11.1 %', '77.8 %', '11.1 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Coulommiers"){
# li.push('0.0 %', '87.5 %', '12.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Meaux"){
# li.push('0.0 %', '80.75 %', '19.25 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Melun"){
# li.push('56.5 %', '4.3 %', '39.09 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Melun"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "La Rochette"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Formation professionnelle" && filiere_agregee == "Autre formation" &&  lieu == "Champs-sur-Marne"){
# li.push('90.89 %', '9.1 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Marne-la-Vallée"){
# li.push('90.19 %', '3.7 %', '6.1 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Marne-la-Vallée"){
# li.push('65.39 %', '22.75 %', '11.9 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Germain-en-Laye"){
# li.push('70.39 %', '0.0 %', '29.6 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Germain-en-Laye"){
# li.push('0.0 %', '57.09 %', '42.9 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Germain-en-Laye"){
# li.push('69.8 %', '9.4 %', '20.8 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Germain-en-Laye"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Versailles"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Versailles"){
# li.push('90.2 %', '2.15 %', '7.7 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Guyancourt"){
# li.push('46.2 %', '30.8 %', '23.1 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Sartrouville"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Sartrouville"){
# li.push('50.0 %', '16.7 %', '33.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Niort"){
# li.push('0.0 %', '50.0 %', '50.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Niort"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Bressuire"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Bressuire"){
# li.push('25.0 %', '43.8 %', '31.3 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('78.24 %', '0.0 %', '21.75 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('85.73 %', '0.0 %', '14.26 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('66.69 %', '0.0 %', '33.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('0.0 %', '83.34 %', '16.65 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Classe préparatoire aux études supérieures" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('90.0 %', '5.0 %', '5.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('57.7 %', '26.9 %', '15.4 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('50.83 %', '11.1 %', '38.03 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Amiens"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Albi"){
# li.push('13.65 %', '81.8 %', '4.55 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Albi"){
# li.push('36.1 %', '22.23 %', '41.67 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Montauban"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Raphaël"){
# li.push('50.0 %', '37.5 %', '12.5 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Toulon"){
# li.push('50.0 %', '14.3 %', '35.7 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Toulon"){
# li.push('0.0 %', '96.15 %', '3.85 %')
# }
# if (filiere == "Formation professionnelle" && filiere_agregee == "Autre formation" &&  lieu == "Toulon"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Toulon"){
# li.push('61.98 %', '10.63 %', '27.38 %')
# }
# if (filiere == "Formation des écoles supérieure d'art" && filiere_agregee == "Autre formation" &&  lieu == "Toulon"){
# li.push('72.19 %', '11.1 %', '16.7 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "La Garde"){
# li.push('91.2 %', '2.95 %', '5.9 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "La Garde"){
# li.push('50.0 %', '15.0 %', '35.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Avignon"){
# li.push('55.59 %', '0.0 %', '44.4 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Avignon"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Avignon"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Avignon"){
# li.push('0.0 %', '75.0 %', '25.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Avignon"){
# li.push('97.61 %', '0.0 %', '2.38 %')
# }
# if (filiere == "Classe préparatoire aux études supérieures" && filiere_agregee == "Autre formation" &&  lieu == "Avignon"){
# li.push('66.69 %', '0.0 %', '33.3 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "La Roche-sur-Yon"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "La Roche-sur-Yon"){
# li.push('20.0 %', '50.0 %', '30.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Fontenay-le-Comte"){
# li.push('59.09 %', '0.0 %', '40.9 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('62.9 %', '0.0 %', '37.09 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('77.77 %', '0.0 %', '22.23 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('57.09 %', '42.9 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('16.67 %', '83.33 %', '0.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('65.2 %', '13.8 %', '20.95 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Poitiers"){
# li.push('99.0 %', '0.0 %', '1.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('68.39 %', '0.0 %', '31.6 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('58.35 %', '0.0 %', '41.65 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('5.94 %', '80.8 %', '13.26 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('83.3 %', '8.3 %', '8.3 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('58.34 %', '25.0 %', '16.65 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Limoges"){
# li.push('50.0 %', '0.0 %', '50.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Epinal"){
# li.push('0.0 %', '93.3 %', '6.7 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Epinal"){
# li.push('21.45 %', '78.55 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Dié-des-Vosges"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Dié-des-Vosges"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Sens"){
# li.push('0.0 %', '87.5 %', '12.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Belfort"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Belfort"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Belfort"){
# li.push('12.5 %', '50.0 %', '37.5 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Corbeil-Essonnes"){
# li.push('53.09 %', '0.0 %', '46.9 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Corbeil-Essonnes"){
# li.push('8.0 %', '0.0 %', '92.0 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Corbeil-Essonnes"){
# li.push('80.0 %', '10.0 %', '10.0 %')
# }
# if (filiere == "Classe préparatoire aux études supérieures" && filiere_agregee == "Autre formation" &&  lieu == "Montgeron"){
# li.push('85.69 %', '9.5 %', '4.8 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Orsay"){
# li.push('61.0 %', '0.0 %', '39.0 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Brunoy"){
# li.push('0.0 %', '40.0 %', '60.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Evry-Courcouronnes"){
# li.push('44.7 %', '14.9 %', '40.4 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Evry-Courcouronnes"){
# li.push('67.84 %', '8.35 %', '23.8 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Evry-Courcouronnes"){
# li.push('18.3 %', '54.9 %', '26.8 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Antony"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Boulogne-Billancourt"){
# li.push('5.55 %', '87.79 %', '6.65 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Boulogne-Billancourt"){
# li.push('76.89 %', '0.0 %', '23.1 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Clichy"){
# li.push('61.5 %', '7.7 %', '30.8 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Clichy"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Colombes"){
# li.push('51.65 %', '0.0 %', '48.34 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Nanterre"){
# li.push('25.0 %', '75.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Bagneux"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Ville-d'Avray"){
# li.push('94.09 %', '0.0 %', '5.9 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Châtenay-Malabry"){
# li.push('44.45 %', '31.93 %', '23.61 %')
# }
# if (filiere == "DEJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Châtenay-Malabry"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Courbevoie"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Aubervilliers"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Bondy"){
# li.push('3.85 %', '83.2 %', '12.95 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Bondy"){
# li.push('62.5 %', '26.25 %', '11.25 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Montreuil"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Montreuil"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Montreuil"){
# li.push('40.13 %', '9.1 %', '50.8 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Denis"){
# li.push('77.3 %', '0.0 %', '22.7 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Denis"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Denis"){
# li.push('3.1 %', '81.59 %', '15.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Denis"){
# li.push('1.42 %', '83.34 %', '15.24 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Denis"){
# li.push('75.0 %', '25.0 %', '0.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Denis"){
# li.push('27.16 %', '35.94 %', '36.88 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Aulnay-sous-Bois"){
# li.push('62.5 %', '0.0 %', '37.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Aulnay-sous-Bois"){
# li.push('0.0 %', '86.69 %', '13.3 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Villetaneuse"){
# li.push('60.59 %', '12.1 %', '27.3 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Bobigny"){
# li.push('97.89 %', '0.0 %', '2.1 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Bobigny"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Bobigny"){
# li.push('22.2 %', '48.09 %', '29.6 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Bobigny"){
# li.push('52.59 %', '13.2 %', '34.2 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Tremblay-en-France"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Livry-Gargan"){
# li.push('0.0 %', '80.0 %', '20.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Cachan"){
# li.push('38.7 %', '0.0 %', '61.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Cachan"){
# li.push('0.0 %', '72.0 %', '28.0 %')
# }
# if (filiere == "Formation professionnelle" && filiere_agregee == "Autre formation" &&  lieu == "Cachan"){
# li.push('89.5 %', '0.0 %', '10.5 %')
# }
# if (filiere == "Diplôme d'Etablissement" && filiere_agregee == "Autre formation" &&  lieu == "Cachan"){
# li.push('87.5 %', '0.0 %', '12.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Champigny-sur-Marne"){
# li.push('0.0 %', '93.3 %', '6.7 %')
# }
# if (filiere == "Formations des écoles nationales vétérinaires" && filiere_agregee == "Autre formation" &&  lieu == "Maisons-Alfort"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Nogent-sur-Marne"){
# li.push('22.32 %', '7.15 %', '70.52 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Le Perreux-sur-Marne"){
# li.push('53.59 %', '0.0 %', '46.4 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Vitry-sur-Seine"){
# li.push('0.0 %', '90.0 %', '10.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Vitry-sur-Seine"){
# li.push('51.83 %', '0.0 %', '48.17 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Orly"){
# li.push('0.0 %', '95.5 %', '4.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Vincennes"){
# li.push('0.0 %', '90.0 %', '10.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Vincennes"){
# li.push('47.6 %', '13.1 %', '39.3 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Maur-des-Fossés"){
# li.push('80.0 %', '0.0 %', '20.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Maur-des-Fossés"){
# li.push('28.6 %', '0.0 %', '71.39 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Créteil"){
# li.push('42.59 %', '0.0 %', '57.4 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Créteil"){
# li.push('0.0 %', '73.24 %', '26.75 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Créteil"){
# li.push('22.2 %', '20.0 %', '57.8 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Argenteuil"){
# li.push('73.09 %', '0.0 %', '26.9 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Argenteuil"){
# li.push('0.0 %', '52.4 %', '47.59 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Enghien-les-Bains"){
# li.push('5.55 %', '88.9 %', '5.55 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Cergy"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Cergy"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Cergy"){
# li.push('0.0 %', '69.19 %', '30.8 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Cergy"){
# li.push('96.42 %', '3.57 %', '0.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Cergy"){
# li.push('33.03 %', '37.46 %', '29.5 %')
# }
# if (filiere == "LP - Droit-économie-gestion" && filiere_agregee == "Autre formation" &&  lieu == "Cergy"){
# li.push('45.5 %', '42.4 %', '12.15 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Ajaccio"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Formation professionnelle" && filiere_agregee == "Autre formation" &&  lieu == "Ajaccio"){
# li.push('33.3 %', '0.0 %', '66.69 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Bastia"){
# li.push('94.09 %', '0.0 %', '5.9 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Bastia"){
# li.push('33.3 %', '33.3 %', '33.3 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Corte"){
# li.push('70.0 %', '0.0 %', '30.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Basse-Terre"){
# li.push('5.55 %', '77.8 %', '16.65 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Les Abymes"){
# li.push('91.69 %', '0.0 %', '8.3 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Les Abymes"){
# li.push('75.0 %', '25.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Baie-Mahault"){
# li.push('8.33 %', '86.1 %', '5.57 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Claude"){
# li.push('0.0 %', '91.69 %', '8.3 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Le Gosier"){
# li.push('14.3 %', '85.69 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Le Gosier"){
# li.push('8.3 %', '83.3 %', '8.3 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Fort-de-France"){
# li.push('54.55 %', '0.0 %', '45.45 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Fort-de-France"){
# li.push('50.0 %', '0.0 %', '50.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Fort-de-France"){
# li.push('0.0 %', '89.5 %', '10.5 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Fort-de-France"){
# li.push('7.15 %', '78.55 %', '14.3 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Bellefontaine"){
# li.push('7.7 %', '46.2 %', '46.2 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Schoelcher"){
# li.push('0.0 %', '50.0 %', '50.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Cayenne"){
# li.push('87.5 %', '0.0 %', '12.5 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Cayenne"){
# li.push('50.0 %', '0.0 %', '50.0 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Cayenne"){
# li.push('66.69 %', '16.7 %', '16.7 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Cayenne"){
# li.push('2.27 %', '95.22 %', '2.5 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Le Tampon"){
# li.push('6.5 %', '71.89 %', '21.6 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Le Tampon"){
# li.push('0.0 %', '80.0 %', '20.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Le Tampon"){
# li.push('40.0 %', '44.0 %', '16.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Le Port"){
# li.push('76.5 %', '5.9 %', '17.6 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Le Port"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Paul"){
# li.push('52.9 %', '5.9 %', '41.2 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Paul"){
# li.push('0.0 %', '94.45 %', '5.55 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "La Possession"){
# li.push('8.3 %', '83.3 %', '8.3 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Benoît"){
# li.push('60.0 %', '0.0 %', '40.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Saint-Benoît"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Faaa"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Faaa"){
# li.push('0.0 %', '60.0 %', '40.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Faaa"){
# li.push('13.8 %', '75.89 %', '10.3 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('63.0 %', '0.0 %', '37.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('44.44 %', '0.0 %', '55.55 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('64.69 %', '11.8 %', '23.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('10.3 %', '86.93 %', '2.77 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('14.3 %', '7.1 %', '78.59 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Orléans"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Chalon-sur-Saône"){
# li.push('73.3 %', '0.0 %', '26.7 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Chalon-sur-Saône"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Chalon-sur-Saône"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Eysines"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Lyon"){
# li.push('67.5 %', '5.0 %', '27.5 %')
# }
# if (filiere == "Formation professionnelle" && filiere_agregee == "Autre formation" &&  lieu == "Lyon"){
# li.push('82.42 %', '0.4 %', '17.15 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Lyon"){
# li.push('44.43 %', '25.2 %', '30.37 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Lyon"){
# li.push('88.89 %', '0.0 %', '11.1 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('76.0 %', '2.0 %', '22.0 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('84.5 %', '3.4 %', '12.1 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('81.17 %', '5.0 %', '13.82 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('21.2 %', '15.4 %', '63.5 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('50.0 %', '12.5 %', '37.5 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Clermont-Ferrand"){
# li.push('78.59 %', '14.3 %', '7.1 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Manosque"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Tourcoing"){
# li.push('90.0 %', '0.0 %', '10.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Tourcoing"){
# li.push('nan %', 'nan %', 'nan %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Tourcoing"){
# li.push('25.35 %', '4.55 %', '70.09 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Dijon"){
# li.push('78.64 %', '0.0 %', '21.35 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Dijon"){
# li.push('77.8 %', '0.0 %', '22.2 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Dijon"){
# li.push('0.0 %', '66.67 %', '33.33 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Dijon"){
# li.push('45.7 %', '17.1 %', '37.09 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Dijon"){
# li.push('66.65 %', '33.34 %', '0.0 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Dijon"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('67.29 %', '0.0 %', '32.7 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('90.19 %', '3.3 %', '6.5 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('88.14 %', '0.0 %', '11.86 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('76.5 %', '0.0 %', '23.5 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('65.5 %', '6.22 %', '28.3 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('3.69 %', '81.39 %', '14.92 %')
# }
# if (filiere == "Formation professionnelle" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('16.7 %', '83.3 %', '0.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Classe préparatoire aux études supérieures" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('73.3 %', '6.7 %', '20.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('58.33 %', '0.0 %', '41.67 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('52.91 %', '14.53 %', '32.57 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Formations des écoles nationales vétérinaires" && filiere_agregee == "Autre formation" &&  lieu == "Toulouse"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Sainte-Savine"){
# li.push('0.0 %', '83.3 %', '16.7 %')
# }
# if (filiere == "Diplôme National d'Art" && filiere_agregee == "Autre formation" &&  lieu == "Bourges"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Classe préparatoire aux études supérieures" && filiere_agregee == "Autre formation" &&  lieu == "Bourges"){
# li.push('87.0 %', '8.7 %', '4.3 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Bourges"){
# li.push('68.2 %', '9.1 %', '22.75 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('5.0 %', '95.0 %', '0.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Classe préparatoire aux études supérieures" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('94.09 %', '0.0 %', '5.9 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('33.33 %', '0.0 %', '66.67 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('56.3 %', '0.0 %', '43.8 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('47.5 %', '20.82 %', '31.67 %')
# }
# if (filiere == "Sciences politiques" && filiere_agregee == "Autre formation" &&  lieu == "Reims"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('57.7 %', '0.0 %', '42.3 %')
# }
# if (filiere == "CUPGE - Sciences, technologie, santé" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('91.67 %', '8.33 %', '0.0 %')
# }
# if (filiere == "Formations Bac + 5" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('81.89 %', '3.6 %', '14.5 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('94.54 %', '0.0 %', '5.46 %')
# }
# if (filiere == "Mise à niveau" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('0.0 %', '100.0 %', '0.0 %')
# }
# if (filiere == "C.M.I - Cursus Master en Ingénierie" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "DEUST" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('80.95 %', '4.15 %', '14.85 %')
# }
# if (filiere == "BPJEPS" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('59.17 %', '14.17 %', '26.67 %')
# }
# if (filiere == "DN MADE" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('33.1 %', '16.55 %', '50.4 %')
# }
# if (filiere == "Diplôme d'Université" && filiere_agregee == "Autre formation" &&  lieu == "Montpellier"){
# li.push('63.2 %', '10.7 %', '26.13 %')
# }
# if (filiere == "DCG" && filiere_agregee == "Autre formation" &&  lieu == "Lille"){
# li.push('81.59 %', '0.0 %', '18.4 %')
# }
# if (filiere == "D.E secteur sanitaire" && filiere_agregee == "Autre formation" &&  lieu == "Lille"){
# li.push('89.87 %', '0.0 %', '10.12 %')
# }
# if (filiere == "Année préparatoire" && filiere_agregee == "Autre formation" &&  lieu == "Lille"){
# li.push('84.27 %', '0.0 %', '15.73 %')
# }
# if (filiere == "Mention complémentaire" && filiere_agregee == "Autre formation" &&  lieu == "Lille"){
# ...
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Marseille  3e  Arrondissement"){
# li.push('99.03 %', '0.0 %', '0.97 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Marseille 13e  Arrondissement"){
# li.push('88.19 %', '0.0 %', '11.8 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Cholet"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Cholet"){
# li.push('84.0 %', '8.0 %', '8.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Valenciennes"){
# li.push('77.3 %', '3.8 %', '18.95 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Valenciennes"){
# li.push('63.59 %', '0.0 %', '36.4 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Valenciennes"){
# li.push('96.0 %', '4.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Angers"){
# li.push('85.78 %', '0.0 %', '14.22 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Angers"){
# li.push('95.45 %', '0.0 %', '4.55 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Angers"){
# li.push('84.17 %', '8.88 %', '6.94 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Angers"){
# li.push('96.88 %', '0.0 %', '3.12 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Brest"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Brest"){
# li.push('83.16 %', '0.0 %', '16.83 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Brest"){
# li.push('90.89 %', '9.1 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Brest"){
# li.push('85.12 %', '0.0 %', '14.88 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Tours"){
# li.push('77.8 %', '2.8 %', '19.4 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Tours"){
# li.push('95.0 %', '5.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Tours"){
# li.push('89.12 %', '0.0 %', '10.87 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Saint-Etienne"){
# li.push('80.64 %', '1.3 %', '18.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Saint-Etienne"){
# li.push('92.07 %', '0.37 %', '7.56 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Perpignan"){
# li.push('71.25 %', '6.25 %', '22.5 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Perpignan"){
# li.push('93.75 %', '0.0 %', '6.25 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Le Bourget-du-Lac"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Le Bourget-du-Lac"){
# li.push('75.4 %', '4.16 %', '20.42 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Dembeni"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Nancy"){
# li.push('96.3 %', '1.85 %', '1.85 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Nancy"){
# li.push('93.21 %', '0.0 %', '6.78 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Bourg-en-Bresse"){
# li.push('78.59 %', '7.1 %', '14.3 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Strasbourg"){
# li.push('96.23 %', '0.25 %', '3.51 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Jacob-Bellecombette"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Nîmes"){
# li.push('57.9 %', '21.1 %', '21.1 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Nîmes"){
# li.push('73.09 %', '7.7 %', '19.2 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Nîmes"){
# li.push('59.09 %', '0.0 %', '40.9 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Valence"){
# li.push('92.84 %', '0.0 %', '7.15 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Valence"){
# li.push('71.6 %', '0.0 %', '28.4 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Pessac"){
# li.push('81.3 %', '6.3 %', '12.5 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Le Mans"){
# li.push('50.0 %', '0.0 %', '50.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Le Mans"){
# li.push('95.45 %', '0.0 %', '4.55 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Le Mans"){
# li.push('75.0 %', '25.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Le Mans"){
# li.push('86.59 %', '1.13 %', '12.23 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Pau"){
# li.push('97.2 %', '0.0 %', '2.8 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Saint-Martin-d'Hères"){
# li.push('87.44 %', '0.0 %', '12.56 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Saint-Martin-d'Hères"){
# li.push('84.84 %', '2.5 %', '12.65 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Saint-Martin-d'Hères"){
# li.push('92.25 %', '0.0 %', '7.75 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Lyon 8e  Arrondissement"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Châlons-en-Champagne"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Nantes"){
# li.push('92.19 %', '1.45 %', '6.3 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Nantes"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Nantes"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Nantes"){
# li.push('99.0 %', '0.0 %', '1.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Rodez"){
# li.push('62.5 %', '0.0 %', '37.5 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Talence"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Talence"){
# li.push('96.15 %', '0.0 %', '3.85 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Talence"){
# li.push('99.25 %', '0.0 %', '0.75 %')
# }
# if (filiere == "Licence - STAPS" && filiere_agregee == "Licence_Las" &&  lieu == "Talence"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Rennes"){
# li.push('87.5 %', '0.0 %', '12.5 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Rennes"){
# li.push('97.9 %', '0.0 %', '2.1 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Rennes"){
# li.push('94.12 %', '0.92 %', '4.95 %')
# }
# if (filiere == "Licence - STAPS" && filiere_agregee == "Licence_Las" &&  lieu == "Rennes"){
# li.push('95.74 %', '0.0 %', '4.25 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Laval"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Besançon"){
# li.push('81.45 %', '10.0 %', '8.55 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Besançon"){
# li.push('95.5 %', '0.0 %', '4.5 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Besançon"){
# li.push('92.55 %', '4.35 %', '3.12 %')
# }
# if (filiere == "Licence - STAPS" && filiere_agregee == "Licence_Las" &&  lieu == "Besançon"){
# li.push('91.8 %', '2.0 %', '6.1 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Quimper"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Caen"){
# li.push('95.74 %', '0.65 %', '3.6 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Caen"){
# li.push('94.65 %', '0.0 %', '5.35 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Caen"){
# li.push('97.61 %', '0.98 %', '1.4 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Troyes"){
# li.push('74.99 %', '6.8 %', '18.2 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Metz"){
# li.push('64.54 %', '6.65 %', '28.8 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Metz"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Metz"){
# li.push('92.48 %', '6.28 %', '1.26 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Nice"){
# li.push('81.47 %', '7.23 %', '11.32 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Nice"){
# li.push('96.65 %', '0.0 %', '3.35 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Nice"){
# li.push('72.19 %', '5.6 %', '22.2 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Nice"){
# li.push('94.06 %', '0.0 %', '5.93 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Arles"){
# li.push('66.69 %', '11.1 %', '22.2 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Lens"){
# li.push('93.46 %', '0.0 %', '6.53 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Charleville-Mézières"){
# li.push('57.09 %', '0.0 %', '42.9 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Marseille  9e  Arrondissement"){
# li.push('95.13 %', '1.27 %', '3.6 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Saint-Brieuc"){
# li.push('82.09 %', '3.6 %', '14.3 %')
# }
# if (filiere == "Licence - Sciences humaines et sociales" && filiere_agregee == "Licence_Las" &&  lieu == "Lorient"){
# li.push('93.34 %', '0.0 %', '6.65 %')
# }
# if (filiere == "Licence - Arts-lettres-langues" && filiere_agregee == "Licence_Las" &&  lieu == "Lorient"){
# li.push('83.28 %', '4.0 %', '12.72 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Lorient"){
# li.push('88.9 %', '0.0 %', '11.1 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Agen"){
# li.push('82.59 %', '4.3 %', '13.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Cambrai"){
# li.push('90.89 %', '0.0 %', '9.1 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Vannes"){
# li.push('83.74 %', '0.0 %', '16.25 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Vannes"){
# li.push('96.95 %', '0.0 %', '3.05 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Boulogne-sur-Mer"){
# li.push('69.59 %', '0.0 %', '30.4 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Calais"){
# li.push('91.89 %', '0.0 %', '8.1 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Villeurbanne"){
# li.push('91.94 %', '0.0 %', '8.05 %')
# }
# if (filiere == "Licence - STAPS" && filiere_agregee == "Licence_Las" &&  lieu == "Cuffies"){
# li.push('85.69 %', '0.0 %', '14.3 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Narbonne"){
# li.push('36.8 %', '5.3 %', '57.9 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Marseille  1er Arrondissement"){
# li.push('79.34 %', '3.7 %', '16.95 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Brive-la-Gaillarde"){
# li.push('66.69 %', '0.0 %', '33.3 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Périgueux"){
# li.push('71.39 %', '0.0 %', '28.6 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Evreux"){
# li.push('90.0 %', '0.0 %', '10.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Gap"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Le Creusot"){
# li.push('100.0 %', '0.0 %', '0.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Damigny"){
# li.push('96.0 %', '2.0 %', '2.0 %')
# }
# if (filiere == "Licence - Sciences - technologies - santé" && filiere_agregee == "Licence_Las" &&  lieu == "Font-Romeu-Odeillo-Via"){
# li.push('75.0 %', '0.0 %', '25.0 %')
# }
# if (filiere == "Licence - Droit-économie-gestion" && filiere_agregee == "Licence_Las" &&  lieu == "Draguignan"){
# li.push('66.69 %', '33.3 %', '0.0 %')
# }

# %%
for fil in liste_filiere_agregee:
    for dep in liste_departement:
    
        #print(reg,fil)
        df_bis = moyenne_par_departement_et_formation_agregee(dep,fil)
        df_bis = df_bis.reset_index()      
        for filiere in liste_de_filiere:
            dfi = df_bis[df_bis["Filière de formation"]==filiere]
            if len(dfi)!=0:
                proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
                proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
                proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
                t_uple = str((proba_g,proba_p,proba_t))
                print('if (filiere == "'+filiere+'" && filiere_agregee == "'+fil+'" &&  lieu == "'+dep+'"){\nli.push'+t_uple+'\n}')

# %%
for fil in liste_filiere_agregee:
    for ville in liste_ville:
        chaine = ""
        #print(reg,fil)
        df_bis = moyenne_par_ville_et_formation_agregee(ville,fil)
        df_bis = df_bis.reset_index()      
        li = list(df_bis["Filière de formation"].unique())
        li  =sorted(li)
        for k in li:
            k = k.replace('"',"'")
            chaine += k
            chaine += "|"
            
        print('if (filiere == "'+fil+'" && lieu == "'+ville+'"){\nchaine_villes="'+chaine+'"\n}')

# %%
for fil in liste_filiere_agregee:
    for reg in liste_de_regions:
        chaine = ""
        #print(reg,fil)
        df_bis = moyenne_par_region_et_formation_agregee(reg,fil)
        df_bis = df_bis.reset_index()      
        li = list(df_bis["Filière de formation"].unique())
        li  =sorted(li)
        for k in li:
            k = k.replace('"',"'")
            chaine += k
            chaine += "|"
            
        print('if (filiere == "'+fil+'" && lieu == "'+reg+'"){\nchaine_villes="'+chaine+'"\n}')

# %%
for fil in liste_filiere_agregee:
    for dep in liste_departement:
        chaine = ""
        #print(reg,fil)
        df_bis = moyenne_par_departement_et_formation_agregee(dep,fil)
        df_bis = df_bis.reset_index()      
        li = list(df_bis["Filière de formation"].unique())
        li  =sorted(li)
        for k in li:
            k = k.replace('"',"'")
            chaine += k
            chaine += "|"
            
        print('if (filiere == "'+fil+'" && lieu == "'+dep+'"){\nchaine_villes="'+chaine+'"\n}')

# %%
#RETOUR_FIL A RELANCER
for fil in liste_de_filiere:
    for reg in liste_de_regions:
        chaine = ""
        #print(reg,fil)
        df_bis = moyenne_par_region_et_formation(reg,fil)
        df_bis = df_bis.reset_index()      
        li = list(df_bis["Filière de formation détaillée bis"].unique())
        li  =sorted(li)
        for k in li:
            k = k.replace('"',"'")
            chaine += k
            chaine += "|"
        if chaine!="": 
            print('if (filiere == "'+fil+'" && lieu == "'+reg+'"){\nchaine_villes="'+chaine+'"\n}')

# %%
for fil in liste_de_filiere:
    for reg in liste_ville:
        chaine = ""
        #print(reg,fil)
        df_bis = moyenne_par_ville_et_formation(reg,fil)
        df_bis = df_bis.reset_index()      
        li = list(df_bis["Filière de formation détaillée bis"].unique())
        li  =sorted(li)
        for k in li:
            k = k.replace('"',"'")
            chaine += k
            chaine += "|"
        if chaine!="":     
            print('if (filiere == "'+fil+'" && lieu == "'+reg+'"){\nchaine_villes="'+chaine+'"\n}')

# %%
for fil in liste_de_filiere:
    for reg in liste_departement:
        chaine = ""
        #print(reg,fil)
        df_bis = moyenne_par_departement_et_formation(reg,fil)
        df_bis = df_bis.reset_index()      
        li = list(df_bis["Filière de formation détaillée bis"].unique())
        li  =sorted(li)
        for k in li:
            k = k.replace('"',"'")
            chaine += k
            chaine += "|"
        if chaine!="":  
            print('if (filiere == "'+fil+'" && lieu == "'+reg+'"){\nchaine_villes="'+chaine+'"\n}')

# %%
liste_filiere_bis = list(df["Filière de formation détaillée bis"].unique())
len(liste_filiere_bis)
# Out:
# 521

# %%
#PROBA BIS
for fil in liste_de_filiere:
    for reg in liste_de_regions:
    
        #print(reg,fil)
        df_bis = moyenne_par_region_et_formation(reg,fil)
        df_bis = df_bis.reset_index()      
        for bis in liste_filiere_bis:
            dfi = df_bis[df_bis["Filière de formation détaillée bis"]==bis]
            if len(dfi)!=0:
                proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
                proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
                proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
                t_uple = str((proba_g,proba_p,proba_t))
            
                print('if (filiere == "'+fil+'" && filiere_bis == "'+bis+'" &&  lieu == "'+reg+'"){\nli.push'+t_uple+'\n}')

# %%
for fil in liste_de_filiere:
    for ville in liste_ville:
    
        #print(reg,fil)
        df_bis = moyenne_par_ville_et_formation(ville,fil)
        df_bis = df_bis.reset_index()      
        for bis in liste_filiere_bis:
            dfi = df_bis[df_bis["Filière de formation détaillée bis"]==bis]
            if len(dfi)!=0:
                proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
                proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
                proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
                t_uple = str((proba_g,proba_p,proba_t))
            
                print('if (filiere == "'+fil+'" && filiere_bis == "'+bis+'" &&  lieu == "'+ville+'"){\nli.push'+t_uple+'\n}')

# %%
for fil in liste_de_filiere:
    for dep in liste_departement:
    
        #print(reg,fil)
        df_bis = moyenne_par_departement_et_formation(dep,fil)
        df_bis = df_bis.reset_index()      
        for bis in liste_filiere_bis:
            dfi = df_bis[df_bis["Filière de formation détaillée bis"]==bis]
            if len(dfi)!=0:
                proba_g = str(round(dfi["% d’admis néo bacheliers généraux"].mean(),2))+" %"
                proba_p = str(round(dfi["% d’admis néo bacheliers professionnels"].mean(),2))+" %"
                proba_t = str(round(dfi["% d’admis néo bacheliers technologiques"].mean(),2))+" %"
                t_uple = str((proba_g,proba_p,proba_t))
            
                print('if (filiere == "'+fil+'" && filiere_bis == "'+bis+'" &&  lieu == "'+dep+'"){\nli.push'+t_uple+'\n}')

# %%
liste_de_filiere = sorted(liste_de_filiere)
for fil in liste_de_filiere:
    print('<option value="'+fil+'">'+fil+'</option>')

# %%
liste_de_filiere_bis = sorted(list(df["Filière de formation détaillée bis"].unique()))

for fil in liste_de_filiere_bis:
    print('<option value="'+fil+'">'+fil+'</option>')
# Out:
# <option value="Accueil d'excellence en tourisme">Accueil d'excellence en tourisme</option>
# <option value="Accueil dans transports">Accueil dans transports</option>
# <option value="Accueil réception">Accueil réception</option>
# <option value="Acoustique et Vibrations">Acoustique et Vibrations</option>
# <option value="Activités aquatiques et de la natation">Activités aquatiques et de la natation</option>
# <option value="Activités de la forme">Activités de la forme</option>
# <option value="Activités physiques et sportives adaptées : déficiences intellectuelles, troubles psychiques">Activités physiques et sportives adaptées : déficiences intellectuelles, troubles psychiques</option>
# <option value="Activités physiques et sportives et inadaptations sociales">Activités physiques et sportives et inadaptations sociales</option>
# <option value="Activités physiques pour tous">Activités physiques pour tous</option>
# <option value="Activités physiques pour tous / Activités sports collectifs">Activités physiques pour tous / Activités sports collectifs</option>
# <option value="Activités sports collectifs">Activités sports collectifs</option>
# <option value="Administration et Echanges internationaux">Administration et Echanges internationaux</option>
# <option value="Administration publique">Administration publique</option>
# <option value="Administration économique et sociale">Administration économique et sociale</option>
# <option value="Agent de contrôle non destructif">Agent de contrôle non destructif</option>
# <option value="Agronomie : Productions végétales">Agronomie : Productions végétales</option>
# <option value="Aménagements paysagers">Aménagements paysagers</option>
# <option value="Analyse des milieux biologiques">Analyse des milieux biologiques</option>
# <option value="Analyse, conduite et stratégie de l'entreprise agricole">Analyse, conduite et stratégie de l'entreprise agricole</option>
# <option value="Analyses agricoles biologiques et biotechnologiques">Analyses agricoles biologiques et biotechnologiques</option>
# <option value="Analyses de biologie médicale">Analyses de biologie médicale</option>
# <option value="Anglais / Langue asiatique">Anglais / Langue asiatique</option>
# <option value="Animation">Animation</option>
# <option value="Animation et gestion des activités physiques, sportives ou culturelles">Animation et gestion des activités physiques, sportives ou culturelles</option>
# <option value="Animation et gestion des activités sportives, physiques ou culturelles, parcours activités aquatiques">Animation et gestion des activités sportives, physiques ou culturelles, parcours activités aquatiques</option>
# <option value="Animation et gestion des activités sportives, physiques ou culturelles, parcours activités de pleine nature">Animation et gestion des activités sportives, physiques ou culturelles, parcours activités de pleine nature</option>
# <option value="Animation et gestion des activités sportives, physiques ou culturelles, parcours agent de développement de club sportif">Animation et gestion des activités sportives, physiques ou culturelles, parcours agent de développement de club sportif</option>
# <option value="Animation et gestion des activités sportives, physiques ou culturelles, parcours animation">Animation et gestion des activités sportives, physiques ou culturelles, parcours animation</option>
# <option value="Animation, commercialisation des services sportifs">Animation, commercialisation des services sportifs</option>
# <option value="Animation-gestion de projets dans le secteur sportif">Animation-gestion de projets dans le secteur sportif</option>
# <option value="Année préparatoire">Année préparatoire</option>
# <option value="Année préparatoire à l'École Nationale de la Marine Marchande - Officier 1ère classe">Année préparatoire à l'École Nationale de la Marine Marchande - Officier 1ère classe</option>
# <option value="Aquaculture">Aquaculture</option>
# <option value="Architecture">Architecture</option>
# <option value="Architectures en Métal : conception et Réalisation">Architectures en Métal : conception et Réalisation</option>
# <option value="Archéologie, histoire de l'art, anthropologie">Archéologie, histoire de l'art, anthropologie</option>
# <option value="Arts">Arts</option>
# <option value="Arts du spectacle">Arts du spectacle</option>
# <option value="Arts plastiques">Arts plastiques</option>
# <option value="Assistance Conseil Vente à distance">Assistance Conseil Vente à distance</option>
# <option value="Assistance technique d'ingénieur">Assistance technique d'ingénieur</option>
# <option value="Assistant ingénieur en biologie, biochimie, biotechnologie">Assistant ingénieur en biologie, biochimie, biotechnologie</option>
# <option value="Assistant ingénieur en biologie-biochimie - biotechnologies (bac +3)">Assistant ingénieur en biologie-biochimie - biotechnologies (bac +3)</option>
# <option value="Assistant juridique">Assistant juridique</option>
# <option value="Assurance">Assurance</option>
# <option value="Aéronautique">Aéronautique</option>
# <option value="Aéronautique - option avionique">Aéronautique - option avionique</option>
# <option value="Aéronautique option avions à moteur à pistons">Aéronautique option avions à moteur à pistons</option>
# <option value="Aéronautique option avions à moteur à turbines">Aéronautique option avions à moteur à turbines</option>
# <option value="Aéronautique option hélicoptère moteur à turbines">Aéronautique option hélicoptère moteur à turbines</option>
# <option value="B/L - Lettres et sciences sociales">B/L - Lettres et sciences sociales</option>
# <option value="BCPST">BCPST</option>
# <option value="Banque conseiller de clientèle">Banque conseiller de clientèle</option>
# <option value="Bicursus Architecture Ingénieur">Bicursus Architecture Ingénieur</option>
# <option value="Bioanalyses et contrôles">Bioanalyses et contrôles</option>
# <option value="Bioqualité">Bioqualité</option>
# <option value="Biotechnologies">Biotechnologies</option>
# <option value="Bureautique et Communication Multimédia">Bureautique et Communication Multimédia</option>
# <option value="Bâtiment">Bâtiment</option>
# <option value="Bâtiment et Construction">Bâtiment et Construction</option>
# <option value="Bâtiment et travaux publics">Bâtiment et travaux publics</option>
# <option value="CPES - Arts">CPES - Arts</option>
# <option value="CPES - Générale">CPES - Générale</option>
# <option value="CPES - Littéraire">CPES - Littéraire</option>
# <option value="CPES - Sciences économiques">CPES - Sciences économiques</option>
# <option value="CPES - Scientifique">CPES - Scientifique</option>
# <option value="Cadre technique génie de l'environnement marin">Cadre technique génie de l'environnement marin</option>
# <option value="Cadre technique production et valorisation des ressources marines">Cadre technique production et valorisation des ressources marines</option>
# <option value="Canoë-Kayak">Canoë-Kayak</option>
# <option value="Carrières juridiques">Carrières juridiques</option>
# <option value="Carrières sociales Parcours animation sociale et socioculturelle">Carrières sociales Parcours animation sociale et socioculturelle</option>
# <option value="Carrières sociales Parcours assistance sociale">Carrières sociales Parcours assistance sociale</option>
# <option value="Carrières sociales Parcours éducation spécialisée">Carrières sociales Parcours éducation spécialisée</option>
# <option value="Carrières sociales parcours coordination et gestion des établissements et services sanitaires et sociaux">Carrières sociales parcours coordination et gestion des établissements et services sanitaires et sociaux</option>
# <option value="Carrières sociales parcours villes et territoires durables">Carrières sociales parcours villes et territoires durables</option>
# <option value="Certificat de capacité d'Orthophoniste">Certificat de capacité d'Orthophoniste</option>
# <option value="Certificat de capacité d'Orthoptiste">Certificat de capacité d'Orthoptiste</option>
# <option value="Chargé de mission qualité, sécurité, santé au travail et environnement (Bac + 3)">Chargé de mission qualité, sécurité, santé au travail et environnement (Bac + 3)</option>
# <option value="Chargé de projet en aménagement durable du territoire (bac +2)">Chargé de projet en aménagement durable du territoire (bac +2)</option>
# <option value="Chimie">Chimie</option>
# <option value="Chimie, Sciences de la vie">Chimie, Sciences de la vie</option>
# <option value="Cinéma">Cinéma</option>
# <option value="Cinéma et Audiovisuel">Cinéma et Audiovisuel</option>
# <option value="Classe Préparatoire Universitaire - Physique - Chimie">Classe Préparatoire Universitaire - Physique - Chimie</option>
# <option value="Classe Préparatoire Universitaire Mathématiques - Physique - Informatique">Classe Préparatoire Universitaire Mathématiques - Physique - Informatique</option>
# <option value="Classe de mise à niveau au BTS Maritime Pêche et Gestion de l'Environnement Marin">Classe de mise à niveau au BTS Maritime Pêche et Gestion de l'Environnement Marin</option>
# <option value="Commerce International">Commerce International</option>
# <option value="Communication">Communication</option>
# <option value="Comptabilité et gestion">Comptabilité et gestion</option>
# <option value="Conception de processus de découpe et d'emboutissage">Conception de processus de découpe et d'emboutissage</option>
# <option value="Conception de produits industriels">Conception de produits industriels</option>
# <option value="Conception des processus de réalisation de produits (1ère année commune)">Conception des processus de réalisation de produits (1ère année commune)</option>
# <option value="Conception et Réalisation de Systèmes Automatiques">Conception et Réalisation de Systèmes Automatiques</option>
# <option value="Conception et industrialisation en construction navale">Conception et industrialisation en construction navale</option>
# <option value="Conception et industrialisation en microtechniques">Conception et industrialisation en microtechniques</option>
# <option value="Conception et réalisation de carrosseries">Conception et réalisation de carrosseries</option>
# <option value="Conception et réalisation en chaudronnerie industrielle">Conception et réalisation en chaudronnerie industrielle</option>
# <option value="Conseil et commercialisation de solutions techniques">Conseil et commercialisation de solutions techniques</option>
# <option value="Conservation-restauration des biens culturels">Conservation-restauration des biens culturels</option>
# <option value="Contrôle industriel et régulation automatique">Contrôle industriel et régulation automatique</option>
# <option value="Cursus préparatoire aux concours des grandes écoles d'ingénieurs">Cursus préparatoire aux concours des grandes écoles d'ingénieurs</option>
# <option value="Cycle Préparatoire Lettres  - Licence renforcée">Cycle Préparatoire Lettres  - Licence renforcée</option>
# <option value="Cycle Universitaire Préparatoire aux Grandes Ecoles">Cycle Universitaire Préparatoire aux Grandes Ecoles</option>
# <option value="Cycle Universitaire Préparatoire aux Grandes Ecoles - Mathématiques et Physique">Cycle Universitaire Préparatoire aux Grandes Ecoles - Mathématiques et Physique</option>
# <option value="Cycle Universitaire Préparatoire aux Grandes Ecoles - Physique et Mathématiques">Cycle Universitaire Préparatoire aux Grandes Ecoles - Physique et Mathématiques</option>
# <option value="Cycle Universitaire Préparatoire aux Grandes Écoles de commerce">Cycle Universitaire Préparatoire aux Grandes Écoles de commerce</option>
# <option value="Cycle Universitaire de Préparation aux Grandes Ecoles Scientifiques">Cycle Universitaire de Préparation aux Grandes Ecoles Scientifiques</option>
# <option value="Cycle pluridisciplinaire d'Études Supérieures - Humanités">Cycle pluridisciplinaire d'Études Supérieures - Humanités</option>
# <option value="Cycle pluridisciplinaire d'Études Supérieures - SESJ">Cycle pluridisciplinaire d'Études Supérieures - SESJ</option>
# <option value="Cycle pluridisciplinaire d'Études Supérieures - Sciences">Cycle pluridisciplinaire d'Études Supérieures - Sciences</option>
# <option value="Cycle pluridisciplinaire d'Études Supérieures - Sciences et sociétés">Cycle pluridisciplinaire d'Études Supérieures - Sciences et sociétés</option>
# <option value="Cycle préparatoire Physique Chimie, parcours renforcé">Cycle préparatoire Physique Chimie, parcours renforcé</option>
# <option value="Cycle universitaire préparatoire aux grandes écoles">Cycle universitaire préparatoire aux grandes écoles</option>
# <option value="Cycle universitaire préparatoire aux grandes écoles - Mécanique">Cycle universitaire préparatoire aux grandes écoles - Mécanique</option>
# <option value="Cycle universitaire préparatoire aux grandes écoles - Parcours Informatique, Mathématiques">Cycle universitaire préparatoire aux grandes écoles - Parcours Informatique, Mathématiques</option>
# <option value="Cycle universitaire préparatoire aux grandes écoles - Parcours Sciences pour l'ingénieur">Cycle universitaire préparatoire aux grandes écoles - Parcours Sciences pour l'ingénieur</option>
# <option value="Cycle universitaire préparatoire aux grandes écoles - Physique">Cycle universitaire préparatoire aux grandes écoles - Physique</option>
# <option value="D.E Assistant de Service Social">D.E Assistant de Service Social</option>
# <option value="D.E Audioprothésiste">D.E Audioprothésiste</option>
# <option value="D.E Educateur Spécialisé">D.E Educateur Spécialisé</option>
# <option value="D.E Educateur Technique Spécialisé">D.E Educateur Technique Spécialisé</option>
# <option value="D.E Educateur de Jeunes Enfants">D.E Educateur de Jeunes Enfants</option>
# <option value="D.E Ergothérapeute">D.E Ergothérapeute</option>
# <option value="D.E Infirmier">D.E Infirmier</option>
# <option value="D.E Psychomotricien">D.E Psychomotricien</option>
# <option value="D.E Pédicure-Podologue">D.E Pédicure-Podologue</option>
# <option value="D.E Technicien de Laboratoire Médical">D.E Technicien de Laboratoire Médical</option>
# <option value="D.E manipulateur/trice en électroradiologie médicale">D.E manipulateur/trice en électroradiologie médicale</option>
# <option value="DTS Imagerie médicale et radiologie thérapeutique">DTS Imagerie médicale et radiologie thérapeutique</option>
# <option value="Diplôme National d'Art">Diplôme National d'Art</option>
# <option value="Diplôme National d'Art option art">Diplôme National d'Art option art</option>
# <option value="Diplôme National d'Art option art, mention conservation-restauration des biens culturels">Diplôme National d'Art option art, mention conservation-restauration des biens culturels</option>
# <option value="Diplôme National d'Art option design">Diplôme National d'Art option design</option>
# <option value="Diplôme National d'Art option design, mention design graphique et interactivité">Diplôme National d'Art option design, mention design graphique et interactivité</option>
# <option value="Diplôme d'Etablissement">Diplôme d'Etablissement</option>
# <option value="Diplôme d'Université">Diplôme d'Université</option>
# <option value="Diplôme d'Université - PAREO">Diplôme d'Université - PAREO</option>
# <option value="Diplôme d'Université CAES">Diplôme d'Université CAES</option>
# <option value="Diplôme de Comptabilité et de Gestion">Diplôme de Comptabilité et de Gestion</option>
# <option value="Dispositif SAS - Préparation à l'apprentissage">Dispositif SAS - Préparation à l'apprentissage</option>
# <option value="Diététique">Diététique</option>
# <option value="Droit">Droit</option>
# <option value="Droit et Culture Juridique - Classe Préparatoire (Prépa D1)">Droit et Culture Juridique - Classe Préparatoire (Prépa D1)</option>
# <option value="Droit français - Droit étranger">Droit français - Droit étranger</option>
# <option value="Droit, Economie">Droit, Economie</option>
# <option value="Droit, Informatique">Droit, Informatique</option>
# <option value="Droit, Sciences et Innovation">Droit, Sciences et Innovation</option>
# <option value="Développement de l'agriculture des régions chaudes">Développement de l'agriculture des régions chaudes</option>
# <option value="Développement et Réalisation Bois">Développement et Réalisation Bois</option>
# <option value="Développement, animation des territoires ruraux">Développement, animation des territoires ruraux</option>
# <option value="ECG - Mathématiques appliquées + ESH">ECG - Mathématiques appliquées + ESH</option>
# <option value="ECG - Mathématiques appliquées + HGG">ECG - Mathématiques appliquées + HGG</option>
# <option value="ECG - Mathématiques approfondies + ESH">ECG - Mathématiques approfondies + ESH</option>
# <option value="ECG - Mathématiques approfondies + HGG">ECG - Mathématiques approfondies + HGG</option>
# <option value="ECT - Option technologique">ECT - Option technologique</option>
# <option value="ENS Cachan D2">ENS Cachan D2</option>
# <option value="ENS Rennes D1">ENS Rennes D1</option>
# <option value="Ecole nationale des Chartes">Ecole nationale des Chartes</option>
# <option value="Ecole normale supérieure Paris Saclay ? arts et design">Ecole normale supérieure Paris Saclay ? arts et design</option>
# <option value="Economie">Economie</option>
# <option value="Economie et gestion">Economie et gestion</option>
# <option value="Economie sociale familiale">Economie sociale familiale</option>
# <option value="Economie, Mathématiques">Economie, Mathématiques</option>
# <option value="Edition">Edition</option>
# <option value="Electronique, énergie électrique, automatique">Electronique, énergie électrique, automatique</option>
# <option value="Electrotechnique">Electrotechnique</option>
# <option value="Enveloppe des bâtiments : conception et réalisation">Enveloppe des bâtiments : conception et réalisation</option>
# <option value="Environnement nucléaire">Environnement nucléaire</option>
# <option value="Espace">Espace</option>
# <option value="Etude et réalisation d'agencement">Etude et réalisation d'agencement</option>
# <option value="Etudes culturelles">Etudes culturelles</option>
# <option value="Etudes de réalisation d'un projet de communication - 1ère année commune">Etudes de réalisation d'un projet de communication - 1ère année commune</option>
# <option value="Etudes européennes et internationales">Etudes européennes et internationales</option>
# <option value="Etudes théâtrales">Etudes théâtrales</option>
# <option value="Europlastics et composites à référentiel commun européen - option Conception d'Outillage">Europlastics et composites à référentiel commun européen - option Conception d'Outillage</option>
# <option value="Europlastics et composites à référentiel commun européen - option Pilotage et Optimisation de la production">Europlastics et composites à référentiel commun européen - option Pilotage et Optimisation de la production</option>
# <option value="FCIL -  Métiers du plâtre">FCIL -  Métiers du plâtre</option>
# <option value="FCIL - CAES - Option Production">FCIL - CAES - Option Production</option>
# <option value="FCIL - CAES - Option Services">FCIL - CAES - Option Services</option>
# <option value="FCIL - Entreprenariat Hôtellerie">FCIL - Entreprenariat Hôtellerie</option>
# <option value="FCIL - Environnement Numérique au Service de l'Autonomie de la Personne">FCIL - Environnement Numérique au Service de l'Autonomie de la Personne</option>
# <option value="FCIL - Marchandiseur Visuel Cross Canal">FCIL - Marchandiseur Visuel Cross Canal</option>
# <option value="FCIL - Mobilités Urbaines, maintenances des véhicules électriques légers (Vélos électriques, trottinettes, hoverboards, ...)">FCIL - Mobilités Urbaines, maintenances des véhicules électriques légers (Vélos électriques, trottinettes, hoverboards, ...)</option>
# <option value="FCIL - Parcours polyvalent en recyclage et réhabilitation des véhicules">FCIL - Parcours polyvalent en recyclage et réhabilitation des véhicules</option>
# <option value="FCIL - SVDI (Sureté vidéo détection incendie)">FCIL - SVDI (Sureté vidéo détection incendie)</option>
# <option value="FCIL - Tourneur fraiseur sur machines conventionnelles dans l'aéronautique et l'aérospatiale">FCIL - Tourneur fraiseur sur machines conventionnelles dans l'aéronautique et l'aérospatiale</option>
# <option value="FCIL Adjoint des cadres sanitaires et sociaux - Secrétariat médico-social">FCIL Adjoint des cadres sanitaires et sociaux - Secrétariat médico-social</option>
# <option value="FCIL Administrateur réseau, infrastructure et système numérique">FCIL Administrateur réseau, infrastructure et système numérique</option>
# <option value="FCIL Agent de maitrise de "métré bois"">FCIL Agent de maitrise de "métré bois"</option>
# <option value="FCIL Art et Couture">FCIL Art et Couture</option>
# <option value="FCIL Assistant gestion site web et communication numérique multimédia, à destination des clients et des usagers">FCIL Assistant gestion site web et communication numérique multimédia, à destination des clients et des usagers</option>
# <option value="FCIL Assistant(e) gouvernant">FCIL Assistant(e) gouvernant</option>
# <option value="FCIL BARISTA">FCIL BARISTA</option>
# <option value="FCIL CAO - DAO du bâtiment">FCIL CAO - DAO du bâtiment</option>
# <option value="FCIL Chef de rang">FCIL Chef de rang</option>
# <option value="FCIL Chef de rang à la française - Relais & Chateaux">FCIL Chef de rang à la française - Relais & Chateaux</option>
# <option value="FCIL Commerce international des vins, spiritueux et oenotourisme">FCIL Commerce international des vins, spiritueux et oenotourisme</option>
# <option value="FCIL Communication web et webmarketing">FCIL Communication web et webmarketing</option>
# <option value="FCIL Conseiller commercial en automobile">FCIL Conseiller commercial en automobile</option>
# <option value="FCIL Contrôle Technique">FCIL Contrôle Technique</option>
# <option value="FCIL Crémier-fromager : territoire, art culinaire et vins de champagne">FCIL Crémier-fromager : territoire, art culinaire et vins de champagne</option>
# <option value="FCIL DAide déclarant en douane">FCIL DAide déclarant en douane</option>
# <option value="FCIL Domotique appliquée à la santé / gestion technique de bâtiment">FCIL Domotique appliquée à la santé / gestion technique de bâtiment</option>
# <option value="FCIL E-Commerce">FCIL E-Commerce</option>
# <option value="FCIL Ecole européenne du goût et art de la table">FCIL Ecole européenne du goût et art de la table</option>
# <option value="FCIL Electricien du spectacle">FCIL Electricien du spectacle</option>
# <option value="FCIL Electromobilité">FCIL Electromobilité</option>
# <option value="FCIL Esquisse">FCIL Esquisse</option>
# <option value="FCIL Fibre optique">FCIL Fibre optique</option>
# <option value="FCIL Formation aux compétences numériques de la vente dans l'entreprise">FCIL Formation aux compétences numériques de la vente dans l'entreprise</option>
# <option value="FCIL Formation graphisme et communication visuelle">FCIL Formation graphisme et communication visuelle</option>
# <option value="FCIL Gestion dossier retraite prévoyance et santé">FCIL Gestion dossier retraite prévoyance et santé</option>
# <option value="FCIL Hydro - esthétique">FCIL Hydro - esthétique</option>
# <option value="FCIL Maintenance Milieu Nucléaire">FCIL Maintenance Milieu Nucléaire</option>
# <option value="FCIL Maintenance de 1er niveau des véhicules routiers">FCIL Maintenance de 1er niveau des véhicules routiers</option>
# <option value="FCIL Maroquinerie / Gainerie / Sellerie de luxe">FCIL Maroquinerie / Gainerie / Sellerie de luxe</option>
# <option value="FCIL Moteurs hors bord haute technicité">FCIL Moteurs hors bord haute technicité</option>
# <option value="FCIL Multimédia">FCIL Multimédia</option>
# <option value="FCIL Mécanicien circuit auto">FCIL Mécanicien circuit auto</option>
# <option value="FCIL Mécanicien en compétition automobile - Option monoplace">FCIL Mécanicien en compétition automobile - Option monoplace</option>
# <option value="FCIL Mécanique de compétition - préparation moteurs">FCIL Mécanique de compétition - préparation moteurs</option>
# <option value="FCIL Métiers de Laboratoire">FCIL Métiers de Laboratoire</option>
# <option value="FCIL Nivoculteur">FCIL Nivoculteur</option>
# <option value="FCIL Ouvrier voilier polyvalent">FCIL Ouvrier voilier polyvalent</option>
# <option value="FCIL Projeteur/euse Building Information Modeling (BIM)">FCIL Projeteur/euse Building Information Modeling (BIM)</option>
# <option value="FCIL Prototypiste Mécanicien(ne) Modèle">FCIL Prototypiste Mécanicien(ne) Modèle</option>
# <option value="FCIL Préparation aux concours de la fonction publique concernant les métiers de la sécurité">FCIL Préparation aux concours de la fonction publique concernant les métiers de la sécurité</option>
# <option value="FCIL Responsable d'exécution de travaux de réhabilitation : reprise et rénovation d'ouvrage de Gros ?uvre">FCIL Responsable d'exécution de travaux de réhabilitation : reprise et rénovation d'ouvrage de Gros ?uvre</option>
# <option value="FCIL Restauration Meubles Anciens">FCIL Restauration Meubles Anciens</option>
# <option value="FCIL Santé et bien être de la personne âgée">FCIL Santé et bien être de la personne âgée</option>
# <option value="FCIL Scénographie de la communication">FCIL Scénographie de la communication</option>
# <option value="FCIL Secrétaire juridique">FCIL Secrétaire juridique</option>
# <option value="FCIL Secrétariat Assistant Médico-Social">FCIL Secrétariat Assistant Médico-Social</option>
# <option value="FCIL Secrétariat Médico Social">FCIL Secrétariat Médico Social</option>
# <option value="FCIL Service aux personnes en environnement numérique">FCIL Service aux personnes en environnement numérique</option>
# <option value="FCIL Services aéroportuaires">FCIL Services aéroportuaires</option>
# <option value="FCIL Smart Home">FCIL Smart Home</option>
# <option value="FCIL Sociale Esthétique">FCIL Sociale Esthétique</option>
# <option value="FCIL Sommellerie">FCIL Sommellerie</option>
# <option value="FCIL Son et éclairage en spectacle vivant">FCIL Son et éclairage en spectacle vivant</option>
# <option value="FCIL Technicien de la Transition Energétique du Bâtiment">FCIL Technicien de la Transition Energétique du Bâtiment</option>
# <option value="FCIL Technicien de maintenance et de déploiement numérique">FCIL Technicien de maintenance et de déploiement numérique</option>
# <option value="FCIL Technicien de prise en charge de la personne âgée non autonome option maladie d'alzheimer">FCIL Technicien de prise en charge de la personne âgée non autonome option maladie d'alzheimer</option>
# <option value="FCIL Technicien de systèmes de sécurité et d'incendie">FCIL Technicien de systèmes de sécurité et d'incendie</option>
# <option value="FCIL Technicien des systèmes auxiliaires et véhicules électriques">FCIL Technicien des systèmes auxiliaires et véhicules électriques</option>
# <option value="FCIL Technicien en Maintenance et Conduite de Centrales Photovoltaïques">FCIL Technicien en Maintenance et Conduite de Centrales Photovoltaïques</option>
# <option value="FCIL Technicien motoriste option Mécanique Hors Bord">FCIL Technicien motoriste option Mécanique Hors Bord</option>
# <option value="FCIL Technicien motoriste option Mécanique In Bord">FCIL Technicien motoriste option Mécanique In Bord</option>
# <option value="FCIL Technicien polyvalent dans les systèmes audiovisuels professionnels">FCIL Technicien polyvalent dans les systèmes audiovisuels professionnels</option>
# <option value="FCIL Technicien réseaux très haut débit fibre optique">FCIL Technicien réseaux très haut débit fibre optique</option>
# <option value="FCIL Technicien sur Lignes de Productions Industrielles">FCIL Technicien sur Lignes de Productions Industrielles</option>
# <option value="FCIL Technicien sur centre d'usinage bois 3 et 5 axes - Concepteur sur modeleur 3D">FCIL Technicien sur centre d'usinage bois 3 et 5 axes - Concepteur sur modeleur 3D</option>
# <option value="FCIL Technicien(ne) réseaux et services numériques">FCIL Technicien(ne) réseaux et services numériques</option>
# <option value="FCIL Technico-commercial en équipement de la maison et du multimédia">FCIL Technico-commercial en équipement de la maison et du multimédia</option>
# <option value="FCIL Techniques spécifiques Couture et Luxe">FCIL Techniques spécifiques Couture et Luxe</option>
# <option value="FCIL Visual Merchandising">FCIL Visual Merchandising</option>
# <option value="FCIL Véhicules nautiques motorisés (Jet ski)">FCIL Véhicules nautiques motorisés (Jet ski)</option>
# <option value="FCIL administration de projets dans le secteur du tourisme">FCIL administration de projets dans le secteur du tourisme</option>
# <option value="FCIL agent hydrothermal">FCIL agent hydrothermal</option>
# <option value="FCIL classe passerelle BTS">FCIL classe passerelle BTS</option>
# <option value="FCIL classe passerelle BTS option production">FCIL classe passerelle BTS option production</option>
# <option value="FCIL classe passerelle BTS option service">FCIL classe passerelle BTS option service</option>
# <option value="FCIL maintenance équipements audiovisuels et électroménager">FCIL maintenance équipements audiovisuels et électroménager</option>
# <option value="FCIL préparation aux concours de la sécurité publique et civile">FCIL préparation aux concours de la sécurité publique et civile</option>
# <option value="FCIL secrétariat médical">FCIL secrétariat médical</option>
# <option value="Finitions, aménagement des bâtiments: conception et réalisation">Finitions, aménagement des bâtiments: conception et réalisation</option>
# <option value="Fluide, énergie, domotique - option A génie climatique et fluidique">Fluide, énergie, domotique - option A génie climatique et fluidique</option>
# <option value="Fluide, énergie, domotique - option B froid et conditionnement d'air">Fluide, énergie, domotique - option B froid et conditionnement d'air</option>
# <option value="Fluide, énergie, domotique - option C domotique et bâtiment communicants">Fluide, énergie, domotique - option C domotique et bâtiment communicants</option>
# <option value="Fonderie">Fonderie</option>
# <option value="Forge">Forge</option>
# <option value="Formation Bac + 3">Formation Bac + 3</option>
# <option value="Formation Bac + 4">Formation Bac + 4</option>
# <option value="Formation Bac+6">Formation Bac+6</option>
# <option value="Formation Supérieure de Spécialisation">Formation Supérieure de Spécialisation</option>
# <option value="Formation d'ingénieur Bac + 5">Formation d'ingénieur Bac + 5</option>
# <option value="Formation de base aux métiers du théâtre">Formation de base aux métiers du théâtre</option>
# <option value="Formation des écoles de commerce et de management Bac + 3">Formation des écoles de commerce et de management Bac + 3</option>
# <option value="Formation des écoles de commerce et de management Bac + 4">Formation des écoles de commerce et de management Bac + 4</option>
# <option value="Formation des écoles de commerce et de management Bac + 5">Formation des écoles de commerce et de management Bac + 5</option>
# <option value="Formation des écoles supérieure d'art Bac + 3">Formation des écoles supérieure d'art Bac + 3</option>
# <option value="Formation des écoles supérieure d'art Bac + 5">Formation des écoles supérieure d'art Bac + 5</option>
# <option value="Formation des écoles supérieures de cuisine Bac +3">Formation des écoles supérieures de cuisine Bac +3</option>
# <option value="Formation des écoles supérieures de cuisine Bac +4">Formation des écoles supérieures de cuisine Bac +4</option>
# <option value="Formation valant grade de licence">Formation valant grade de licence</option>
# <option value="Frontières du vivant">Frontières du vivant</option>
# <option value="Gestion">Gestion</option>
# <option value="Gestion administrative et commerciale des organisations">Gestion administrative et commerciale des organisations</option>
# <option value="Gestion de la PME">Gestion de la PME</option>
# <option value="Gestion des entreprises et des administrations">Gestion des entreprises et des administrations</option>
# <option value="Gestion des transports et logistique associée">Gestion des transports et logistique associée</option>
# <option value="Gestion et maitrise de l'eau">Gestion et maitrise de l'eau</option>
# <option value="Gestion et protection de la nature">Gestion et protection de la nature</option>
# <option value="Gestion et protection de la nature / DE d'alpinisme-accompagnateur en moyenne montagne">Gestion et protection de la nature / DE d'alpinisme-accompagnateur en moyenne montagne</option>
# <option value="Gestion forestière">Gestion forestière</option>
# <option value="Gestion logistique et transport">Gestion logistique et transport</option>
# <option value="Gestionnaire d'unité commerciale (option généraliste / option spécialisée) (bac +2)">Gestionnaire d'unité commerciale (option généraliste / option spécialisée) (bac +2)</option>
# <option value="Graphisme">Graphisme</option>
# <option value="Génie biologique Parcours agronomie">Génie biologique Parcours agronomie</option>
# <option value="Génie biologique Parcours diététique et nutrition">Génie biologique Parcours diététique et nutrition</option>
# <option value="Génie biologique parcours biologie médicale et biotechnologie">Génie biologique parcours biologie médicale et biotechnologie</option>
# <option value="Génie biologique parcours sciences de l'aliment et biotechnologie">Génie biologique parcours sciences de l'aliment et biotechnologie</option>
# <option value="Génie biologique parcours sciences de l'environnement et écotechnologies">Génie biologique parcours sciences de l'environnement et écotechnologies</option>
# <option value="Génie chimique génie des procédés">Génie chimique génie des procédés</option>
# <option value="Génie civil">Génie civil</option>
# <option value="Génie civil - Construction durable">Génie civil - Construction durable</option>
# <option value="Génie industriel et maintenance">Génie industriel et maintenance</option>
# <option value="Génie mécanique et productique">Génie mécanique et productique</option>
# <option value="Génie thermique et énergie">Génie thermique et énergie</option>
# <option value="Génie électrique et informatique industrielle">Génie électrique et informatique industrielle</option>
# <option value="Géographie et aménagement">Géographie et aménagement</option>
# <option value="Géologie appliquée">Géologie appliquée</option>
# <option value="Géomètre-Géomaticien (bac +2)">Géomètre-Géomaticien (bac +2)</option>
# <option value="Histoire">Histoire</option>
# <option value="Histoire / Allemand">Histoire / Allemand</option>
# <option value="Histoire / Anglais">Histoire / Anglais</option>
# <option value="Histoire / Géographie">Histoire / Géographie</option>
# <option value="Histoire de l'art et archéologie">Histoire de l'art et archéologie</option>
# <option value="Histoire des Arts">Histoire des Arts</option>
# <option value="Humanités">Humanités</option>
# <option value="Hygiène Sécurité Environnement">Hygiène Sécurité Environnement</option>
# <option value="Hôtellerie restauration">Hôtellerie restauration</option>
# <option value="Industries céramiques">Industries céramiques</option>
# <option value="Information communication Parcours communication des organisations">Information communication Parcours communication des organisations</option>
# <option value="Information communication Parcours information numérique dans les organisations">Information communication Parcours information numérique dans les organisations</option>
# <option value="Information communication Parcours journalisme">Information communication Parcours journalisme</option>
# <option value="Information communication Parcours métiers du livre et du patrimoine">Information communication Parcours métiers du livre et du patrimoine</option>
# <option value="Information communication Parcours publicité">Information communication Parcours publicité</option>
# <option value="Information et communication">Information et communication</option>
# <option value="Informatique">Informatique</option>
# <option value="Informatique d'Organisation des Systèmes d'Information">Informatique d'Organisation des Systèmes d'Information</option>
# <option value="Informatique, Management">Informatique, Management</option>
# <option value="Informatique, Mathématiques">Informatique, Mathématiques</option>
# <option value="Informatique, Sciences de la vie">Informatique, Sciences de la vie</option>
# <option value="Innovation sociale">Innovation sociale</option>
# <option value="Innovations textiles - Option A : Structures">Innovations textiles - Option A : Structures</option>
# <option value="Innovations textiles - Option B : Traitements">Innovations textiles - Option B : Traitements</option>
# <option value="Instrument">Instrument</option>
# <option value="Intervention Sociale">Intervention Sociale</option>
# <option value="Judo-Jujitsu">Judo-Jujitsu</option>
# <option value="Langues étrangères appliquées">Langues étrangères appliquées</option>
# <option value="Langues, littératures & civilisations étrangères et régionales">Langues, littératures & civilisations étrangères et régionales</option>
# <option value="Lettres">Lettres</option>
# <option value="Lettres / Anglais">Lettres / Anglais</option>
# <option value="Lettres / Histoire">Lettres / Histoire</option>
# <option value="Lettres / Sciences du langage">Lettres / Sciences du langage</option>
# <option value="Lettres, langues">Lettres, langues</option>
# <option value="Licence professionnelle">Licence professionnelle</option>
# <option value="Livre">Livre</option>
# <option value="MP2I">MP2I</option>
# <option value="MPSI">MPSI</option>
# <option value="Maintenance des installations oléohydrauliques et pneumatiques">Maintenance des installations oléohydrauliques et pneumatiques</option>
# <option value="Maintenance des matériels de construction et de manutention">Maintenance des matériels de construction et de manutention</option>
# <option value="Maintenance des systèmes - option A Systèmes de production">Maintenance des systèmes - option A Systèmes de production</option>
# <option value="Maintenance des systèmes - option B Systèmes énergétiques et fluidiques">Maintenance des systèmes - option B Systèmes énergétiques et fluidiques</option>
# <option value="Maintenance des systèmes - option C Systèmes éoliens">Maintenance des systèmes - option C Systèmes éoliens</option>
# <option value="Maintenance des systèmes électro-navals">Maintenance des systèmes électro-navals</option>
# <option value="Maintenance des véhicules option motocycles">Maintenance des véhicules option motocycles</option>
# <option value="Maintenance des véhicules option voitures particulières">Maintenance des véhicules option voitures particulières</option>
# <option value="Maintenance des véhicules option véhicules de transport routier">Maintenance des véhicules option véhicules de transport routier</option>
# <option value="Maintenance hôtelière, hospitalière et immobilière">Maintenance hôtelière, hospitalière et immobilière</option>
# <option value="Management Commercial Opérationnel">Management Commercial Opérationnel</option>
# <option value="Management en hôtellerie restauration">Management en hôtellerie restauration</option>
# <option value="Management opérationnel de la sécurité">Management opérationnel de la sécurité</option>
# <option value="Management économique de la construction">Management économique de la construction</option>
# <option value="Manager en Biotechnologies (bac +5)">Manager en Biotechnologies (bac +5)</option>
# <option value="Maquettes et prototypes">Maquettes et prototypes</option>
# <option value="Mathématique - Préparation aux écoles d'ingénieurs">Mathématique - Préparation aux écoles d'ingénieurs</option>
# <option value="Mathématiques">Mathématiques</option>
# <option value="Mathématiques et applications">Mathématiques et applications</option>
# <option value="Mathématiques et informatique appliquées aux sciences humaines et sociales">Mathématiques et informatique appliquées aux sciences humaines et sociales</option>
# <option value="Mathématiques, Physique et Sciences pour l'Ingénieur">Mathématiques, Physique et Sciences pour l'Ingénieur</option>
# <option value="Mathématiques, Sciences de la vie">Mathématiques, Sciences de la vie</option>
# <option value="Mathématiques, physique, chimie, informatique">Mathématiques, physique, chimie, informatique</option>
# <option value="Matériaux">Matériaux</option>
# <option value="Mesures physiques">Mesures physiques</option>
# <option value="Mise à niveau pour l'accès au BTS MASEN">Mise à niveau pour l'accès au BTS MASEN</option>
# <option value="Mode">Mode</option>
# <option value="Moteur à combustion interne">Moteur à combustion interne</option>
# <option value="Musicologie">Musicologie</option>
# <option value="Mécanique">Mécanique</option>
# <option value="Mécatronique navale">Mécatronique navale</option>
# <option value="Médiations citoyennes : éducation, culture, social, environnement">Médiations citoyennes : éducation, culture, social, environnement</option>
# <option value="Métiers de l'animation sociale, socio-éducative et socio-culturelle">Métiers de l'animation sociale, socio-éducative et socio-culturelle</option>
# <option value="Métiers de l'audio-visuel opt : gestion de la production">Métiers de l'audio-visuel opt : gestion de la production</option>
# <option value="Métiers de l'audio-visuel opt : montage et post-production">Métiers de l'audio-visuel opt : montage et post-production</option>
# <option value="Métiers de l'audio-visuel opt : métiers de l'image">Métiers de l'audio-visuel opt : métiers de l'image</option>
# <option value="Métiers de l'audio-visuel opt : métiers du son">Métiers de l'audio-visuel opt : métiers du son</option>
# <option value="Métiers de l'audio-visuel opt : techn. d'ingeniérie et exploit. équipements">Métiers de l'audio-visuel opt : techn. d'ingeniérie et exploit. équipements</option>
# <option value="Métiers de l'eau">Métiers de l'eau</option>
# <option value="Métiers de l'esthétique-cosmétique-parfumerie">Métiers de l'esthétique-cosmétique-parfumerie</option>
# <option value="Métiers de la chimie">Métiers de la chimie</option>
# <option value="Métiers de la cohésion sociale">Métiers de la cohésion sociale</option>
# <option value="Métiers de la coiffure">Métiers de la coiffure</option>
# <option value="Métiers de la forme">Métiers de la forme</option>
# <option value="Métiers de la mesure">Métiers de la mesure</option>
# <option value="Métiers de la mode-chaussure et maroquinerie">Métiers de la mode-chaussure et maroquinerie</option>
# <option value="Métiers de la mode-vêtements">Métiers de la mode-vêtements</option>
# <option value="Métiers des Services à l'environnement">Métiers des Services à l'environnement</option>
# <option value="Métiers des bibliothèques et de la documentation">Métiers des bibliothèques et de la documentation</option>
# <option value="Métiers du géomètre-topographe et de la modélisation numérique">Métiers du géomètre-topographe et de la modélisation numérique</option>
# <option value="Métiers du livre">Métiers du livre</option>
# <option value="Métiers du multimédia et de l'internet">Métiers du multimédia et de l'internet</option>
# <option value="Notariat">Notariat</option>
# <option value="Numérique">Numérique</option>
# <option value="Négociation et digitalisation de la Relation Client">Négociation et digitalisation de la Relation Client</option>
# <option value="Objet">Objet</option>
# <option value="Opticien-Lunetier">Opticien-Lunetier</option>
# <option value="Option lettres et sciences humaines (St Cyr)">Option lettres et sciences humaines (St Cyr)</option>
# <option value="Organisateur de réception">Organisateur de réception</option>
# <option value="Ornement">Ornement</option>
# <option value="PCSI">PCSI</option>
# <option value="PTSI">PTSI</option>
# <option value="Packaging, emballage et conditionnement">Packaging, emballage et conditionnement</option>
# <option value="Parcours d'Accès Spécifique Santé (PASS)">Parcours d'Accès Spécifique Santé (PASS)</option>
# <option value="Parcours mathématiques-physique">Parcours mathématiques-physique</option>
# <option value="Parcours physique-chimie">Parcours physique-chimie</option>
# <option value="Parcours scientifique renforcé">Parcours scientifique renforcé</option>
# <option value="Patrimoine">Patrimoine</option>
# <option value="Paysage">Paysage</option>
# <option value="Paysagiste concepteur">Paysagiste concepteur</option>
# <option value="Peinture décoration">Peinture décoration</option>
# <option value="Philosophie">Philosophie</option>
# <option value="Photographie">Photographie</option>
# <option value="Physique">Physique</option>
# <option value="Physique, chimie">Physique, chimie</option>
# <option value="Pilotage des procédés">Pilotage des procédés</option>
# <option value="Pluridisciplinaire">Pluridisciplinaire</option>
# <option value="Podo-orthésiste">Podo-orthésiste</option>
# <option value="Pratique et gestion des activités physiques, sportives et de loisirs pour les publics séniors">Pratique et gestion des activités physiques, sportives et de loisirs pour les publics séniors</option>
# <option value="Prep'ISIMA">Prep'ISIMA</option>
# <option value="Production horticole">Production horticole</option>
# <option value="Production, contrôles et qualité des produits de santé">Production, contrôles et qualité des produits de santé</option>
# <option value="Professions immobilières">Professions immobilières</option>
# <option value="Prothésiste dentaire">Prothésiste dentaire</option>
# <option value="Prothésiste orthésiste">Prothésiste orthésiste</option>
# <option value="Préparation aux concours des écoles de commerce, Parcours Economie- Finance">Préparation aux concours des écoles de commerce, Parcours Economie- Finance</option>
# <option value="Préparation aux concours des écoles de commerce, Parcours Gestion">Préparation aux concours des écoles de commerce, Parcours Gestion</option>
# <option value="Psychologie">Psychologie</option>
# <option value="Pêche et gestion de l'environnement marin">Pêche et gestion de l'environnement marin</option>
# <option value="Qualité, logistique industrielle et organisation">Qualité, logistique industrielle et organisation</option>
# <option value="Responsable de projets informatiques (bac +3)">Responsable de projets informatiques (bac +3)</option>
# <option value="Responsable technique en bâtiment et travaux publics (bac +2)">Responsable technique en bâtiment et travaux publics (bac +2)</option>
# <option value="Réseaux et télécommunications">Réseaux et télécommunications</option>
# <option value="STAPS, Sciences pour l'ingénieur">STAPS, Sciences pour l'ingénieur</option>
# <option value="Santé environnement : Techniques de laboratoire">Santé environnement : Techniques de laboratoire</option>
# <option value="Santé et société">Santé et société</option>
# <option value="Science et génie des matériaux">Science et génie des matériaux</option>
# <option value="Science politique">Science politique</option>
# <option value="Sciences Po / Instituts d'études politiques - Sciences Humaines et Sociales - Grade Licence">Sciences Po / Instituts d'études politiques - Sciences Humaines et Sociales - Grade Licence</option>
# <option value="Sciences Po / Instituts d'études politiques - Sciences Humaines et Sociales - Grade Master">Sciences Po / Instituts d'études politiques - Sciences Humaines et Sociales - Grade Master</option>
# <option value="Sciences biomédicales">Sciences biomédicales</option>
# <option value="Sciences de l'Homme, Anthropologie, Ethnologie">Sciences de l'Homme, Anthropologie, Ethnologie</option>
# <option value="Sciences de l'éducation">Sciences de l'éducation</option>
# <option value="Sciences de la Terre et Sciences Physiques">Sciences de la Terre et Sciences Physiques</option>
# <option value="Sciences de la Terre et environnement">Sciences de la Terre et environnement</option>
# <option value="Sciences de la Vie et de la Terre : préparation aux concours B Agro et Véto (Sites Saint Charles)">Sciences de la Vie et de la Terre : préparation aux concours B Agro et Véto (Sites Saint Charles)</option>
# <option value="Sciences de la terre">Sciences de la terre</option>
# <option value="Sciences de la vie">Sciences de la vie</option>
# <option value="Sciences de la vie et de la terre">Sciences de la vie et de la terre</option>
# <option value="Sciences du langage">Sciences du langage</option>
# <option value="Sciences et Humanités">Sciences et Humanités</option>
# <option value="Sciences et Techniques des Activités Physiques et Sportives">Sciences et Techniques des Activités Physiques et Sportives</option>
# <option value="Sciences et technologies">Sciences et technologies</option>
# <option value="Sciences et technologies des aliments spécialité Aliments et processus technologiques">Sciences et technologies des aliments spécialité Aliments et processus technologiques</option>
# <option value="Sciences et technologies des aliments spécialité Produits céréaliers">Sciences et technologies des aliments spécialité Produits céréaliers</option>
# <option value="Sciences et technologies des aliments spécialité Produits laitiers">Sciences et technologies des aliments spécialité Produits laitiers</option>
# <option value="Sciences et technologies des aliments spécialité Viandes et produits de la pêche">Sciences et technologies des aliments spécialité Viandes et produits de la pêche</option>
# <option value="Sciences pour l'ingénieur">Sciences pour l'ingénieur</option>
# <option value="Sciences pour la santé">Sciences pour la santé</option>
# <option value="Sciences sanitaires et sociales">Sciences sanitaires et sociales</option>
# <option value="Sciences sociales">Sciences sociales</option>
# <option value="Service et prestation des secteurs sanitaire et social">Service et prestation des secteurs sanitaire et social</option>
# <option value="Services financiers">Services financiers</option>
# <option value="Services informatiques aux organisations">Services informatiques aux organisations</option>
# <option value="Services numériques aux organisations">Services numériques aux organisations</option>
# <option value="Sociologie">Sociologie</option>
# <option value="Spectacle">Spectacle</option>
# <option value="Statistique et informatique décisionnelle">Statistique et informatique décisionnelle</option>
# <option value="Support à l'action managériale">Support à l'action managériale</option>
# <option value="Surf">Surf</option>
# <option value="Systèmes constructifs bois et habitat">Systèmes constructifs bois et habitat</option>
# <option value="Systèmes numériques - Option informatique et réseaux">Systèmes numériques - Option informatique et réseaux</option>
# <option value="Systèmes numériques - Option électronique et communication">Systèmes numériques - Option électronique et communication</option>
# <option value="Systèmes photoniques">Systèmes photoniques</option>
# <option value="TB">TB</option>
# <option value="TPC">TPC</option>
# <option value="TSI">TSI</option>
# <option value="Technicien ascensoriste, service et modernisation">Technicien ascensoriste, service et modernisation</option>
# <option value="Technicien de la mer et du littoral">Technicien de la mer et du littoral</option>
# <option value="Technicien des services à l'énergie">Technicien des services à l'énergie</option>
# <option value="Technicien en chaudronnerie aéronautique et spatiale">Technicien en chaudronnerie aéronautique et spatiale</option>
# <option value="Technicien en peinture aéronautique">Technicien en peinture aéronautique</option>
# <option value="Technicien en réseau électrique">Technicien en réseau électrique</option>
# <option value="Technicien en énergies renouvelables (option thermique)">Technicien en énergies renouvelables (option thermique)</option>
# <option value="Technicien en énergies renouvelables (option énergie électrique)">Technicien en énergies renouvelables (option énergie électrique)</option>
# <option value="Technicien supérieur de maintenance et d'exploitation en climatique (bac +2)">Technicien supérieur de maintenance et d'exploitation en climatique (bac +2)</option>
# <option value="Technicien(ne) en soudage">Technicien(ne) en soudage</option>
# <option value="Technicien(ne) en tuyauterie">Technicien(ne) en tuyauterie</option>
# <option value="Technicien(ne) supérieur(e) en maintenance industrielle (bac +2)">Technicien(ne) supérieur(e) en maintenance industrielle (bac +2)</option>
# <option value="Techniciens Spécialisés de la Construction">Techniciens Spécialisés de la Construction</option>
# <option value="Technico-commercial (BTSA)">Technico-commercial (BTSA)</option>
# <option value="Techniques de commercialisation">Techniques de commercialisation</option>
# <option value="Techniques et services en matériels agricoles">Techniques et services en matériels agricoles</option>
# <option value="Technologies de l'organisation dans les professions de santé">Technologies de l'organisation dans les professions de santé</option>
# <option value="Tennis de table">Tennis de table</option>
# <option value="Théologie">Théologie</option>
# <option value="Théologie Catholique">Théologie Catholique</option>
# <option value="Théologie Protestante">Théologie Protestante</option>
# <option value="Titre professionnel - Organisateur de transports aériens ou maritimes de marchandises (Bac +2)">Titre professionnel - Organisateur de transports aériens ou maritimes de marchandises (Bac +2)</option>
# <option value="Tourisme">Tourisme</option>
# <option value="Traitement des matériaux">Traitement des matériaux</option>
# <option value="Travaux publics">Travaux publics</option>
# <option value="Vendeur-conseil en produits techniques pour l'habitat">Vendeur-conseil en produits techniques pour l'habitat</option>
# <option value="Viticulture-Oenologie">Viticulture-Oenologie</option>
# <option value="Voile multi-supports jusqu'à 6 miles nautique d'un abri">Voile multi-supports jusqu'à 6 miles nautique d'un abri</option>
# <option value="Vélo tout terrain">Vélo tout terrain</option>
# <option value="Webmaster et gestionnaire d'intranet">Webmaster et gestionnaire d'intranet</option>
# <option value="génie des équipements agricoles">génie des équipements agricoles</option>
# <option value="productions animales">productions animales</option>
# <option value="Événement">Événement</option>
